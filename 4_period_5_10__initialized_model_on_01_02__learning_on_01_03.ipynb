# %% [markdown]
# # Introduction
# Here we do a short test of learned model with period range from 5 through 10. It has been initialized and learned on 2020-01-02 day data and after that it is tested on next day data. First part contains figure of PL change during 2 days learning. To compare performance of model there is figure that has been initialized and learned on second day only in second part.

# %%
import pandas as pd
import numpy as np
from pickle import load
import os 
os.chdir('../..')

# %% [markdown]
# ## 1) Initialization on 01-02. Learned on 01-03

# %%
similarity = 90
height, width = 10, 5
window = 5
periods = range(5, 11)

Qmatrix_init = load(open(f'src/SPY_patterns_scanner/output/{similarity}/{width}x{height}/Q_matrix_win{periods[0]}_{periods[-1]}_filter_count.pkl', 'rb'))

count_cols = [col for col in Qmatrix_init.columns if 'count' in col] 
pl_cols = [col for col in Qmatrix_init.columns if 'pl' in col]
# pl_cols[0] = '0pl_iter_0'

buy_cols = [col for col in Qmatrix_init.columns if 'buy' in col]
hold_cols = [col for col in Qmatrix_init.columns if 'hold' in col]
sell_cols = [col for col in Qmatrix_init.columns if 'sell' in col]

columns_to_show = (['date', 'prototype', 'code'] + buy_cols+hold_cols+sell_cols+count_cols+pl_cols).sort()

# %%
Qmatrix_init[pl_cols].sum().plot(rot=45);

# %%
Qmatrix_init[buy_cols + hold_cols + sell_cols]
# Out:
#         buy_5  buy_6  buy_7   buy_8  buy_9  buy_10  hold_5  hold_6  hold_7  \
# 1531   782.81   3.15   3.19    3.12   4.05    1.74   0.000   0.000   0.000
# 20874    0.78  -0.43   1.19  216.73   0.87    1.21   0.000   0.000   0.000
# 25063    0.05   6.14   0.04    0.02  -0.07   -0.05   0.000   0.000   0.000
# 28055   -1.89  -1.06  -4.85   -2.86  -4.98   -3.31   0.000   0.000   0.000
# 38100    0.07  11.46  -0.05    0.16   0.01   -0.05   0.000   0.000   0.000
# 38518   -0.01   0.01   0.01    0.01  -0.08   -0.15   0.000   0.000   0.000
# 39874    0.04   0.08   0.06    0.09   0.05   22.08   0.000   0.000   0.000
# 41722   -0.09   0.02  -0.53   -0.25   0.06   -0.26   0.000   0.000   0.000
# 46321    0.13   0.22   0.03    0.14  70.45    0.15   0.000   0.000   0.000
# 46951   -1.08  -0.68  -2.64   -2.85  -2.94   -2.06  -0.660  -0.660  -0.660
# 47987   -0.01  -0.07  -0.03   -0.05  -0.01   -0.01  -0.001  -0.001  -0.001
# 50884    0.00  -0.03  -0.04   -0.09   0.01    0.01   0.000   0.000   0.000
# 51068   19.60  -0.35   0.02   -0.16   0.09   -0.20   0.000   0.000   0.000
# 51680    0.02   0.05  36.72   -0.12   0.01    0.06   0.000   0.000   0.000
#
#        hold_8  hold_9  hold_10        sell_5  sell_6  sell_7  sell_8  sell_9  \
# 1531    0.000   0.000    0.000 -5.120000e+00   -5.55   -4.66   -1.05   -3.78
# 20874   0.000   0.000    0.000 -2.400000e-01   -0.76   -0.75   -1.06   -0.93
# 25063   0.000   0.000    0.000 -3.000000e-02   -0.03    0.05   -0.09   -0.09
# 28055   0.000   0.000    0.000  6.500000e+02    1.26    3.29    2.80    3.70
# 38100   0.000   0.000    0.000 -1.000000e-01    0.03   -0.13   -0.05   -0.05
# 38518   0.000   0.000    0.000 -1.000000e-02    3.92   -0.06    0.01   -0.01
# 39874   0.000   0.000    0.000 -5.000000e-02   -0.04   -0.04   -0.05   -0.22
# 41722   0.000   0.000    0.000  1.500000e-01    0.28    0.07    0.18   34.98
# 46321   0.000   0.000    0.000 -8.000000e-02   -0.49   -0.14   -0.05   -0.31
# 46951  -0.660  -0.660   -0.660 -1.650000e+00   -0.67   -0.40   -0.66   -1.83
# 47987  -0.001  -0.001   -0.001 -3.000000e-02    2.73   -0.06   -0.35   -0.02
# 50884   0.000   0.000    0.000 -5.684342e-14    0.04    0.09   -0.01    0.01
# 51068   0.000   0.000    0.000  1.200000e-01   -0.09   -0.23    0.11   -0.09
# 51680   0.000   0.000    0.000 -1.000000e-02    0.09   -0.08   -0.26   -0.22
#
#        sell_10
# 1531     -0.94
# 20874    -1.11
# 25063     0.01
# 28055     2.44
# 38100     0.02
# 38518    -0.03
# 39874     0.06
# 41722     0.31
# 46321    -0.36
# 46951    -0.67
# 47987    -0.01
# 50884    11.27
# 51068    -0.09
# 51680    -0.05

# %%
Qmatrix_init[pl_cols].sum()
# Out:
# pl_iter_0      -0.95
# pl_iter_1     119.36
# pl_iter_2     119.61
# pl_iter_3     119.61
# pl_iter_4     119.61
# pl_iter_5     119.61
# pl_iter_6     119.61
# pl_iter_7     119.61
# pl_iter_8     119.61
# pl_iter_9     119.61
# pl_iter_10     74.05
# pl_iter_11     71.58
# pl_iter_12     73.45
# pl_iter_13     75.60
# pl_iter_14     78.59
# pl_iter_15     76.50
# pl_iter_16     74.19
# pl_iter_17     78.15
# pl_iter_18     78.21
# pl_iter_19     78.68
# dtype: float64

# %%
Qmatrix_init[pl_cols].sum().max()
# Out:
# 119.60999999999615

# %% [markdown]
# ## 2)Initialization and learning new model on 01-03

# %%
Qmatrix_03 = load(open(f'src/SPY_patterns_scanner/output/{similarity}/{width}x{height}/Q_matrix_win{periods[0]}_{periods[-1]}_03day_init.pkl', 'rb'))

# %%
pl_cols_03 = [col for col in Qmatrix_03.columns if 'pl' in col]
Qmatrix_03[pl_cols_03].sum().plot(rot=45);

# %%
Qmatrix_03[pl_cols_03].sum()
# Out:
# pl_iter_0    14.56
# pl_iter_1    84.31
# pl_iter_2    97.28
# pl_iter_3    97.28
# pl_iter_4    97.28
# pl_iter_5    97.28
# dtype: float64

# %% [markdown]
# # Conclusion
# As result model has been learned successfully. It has brought positive PL = 74.05  on first iteration. The model initialized and learned on 2020-01-02 only got top result PL = 97.28 what is 30% greater than test results for model with period range 5 - 10.
